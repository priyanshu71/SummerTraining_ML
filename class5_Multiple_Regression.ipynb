# %% [markdown]
# # Multicollinearity in Linear Regression

# %%
import pandas as pd

# %%
import statsmodels.api as sm #This library consists of Different Regression Model
df_adv = pd.read_csv('Advertising.csv', index_col=0)
X = df_adv[['TV', 'Radio', 'Newspaper']]
y = df_adv['Sales']
df_adv.head()

# sales = b0*1 + b1*tv + b2*radio + b3*newspaper
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
X = sm.add_constant(X)

# %%
X
# Out:
#      const     TV  Radio  Newspaper
# 1      1.0  230.1   37.8       69.2
# 2      1.0   44.5   39.3       45.1
# 3      1.0   17.2   45.9       69.3
# 4      1.0  151.5   41.3       58.5
# 5      1.0  180.8   10.8       58.4
# ..     ...    ...    ...        ...
# 196    1.0   38.2    3.7       13.8
# 197    1.0   94.2    4.9        8.1
# 198    1.0  177.0    9.3        6.4
# 199    1.0  283.6   42.0       66.2
# 200    1.0  232.1    8.6        8.7
#
# [200 rows x 4 columns]

# %%
#fit a OLS model with intercept on TV and Radio

model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Wed, 16 Jun 2021   Prob (F-statistic):           1.58e-96
# Time:                        10:57:29   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.9389      0.312      9.422      0.000       2.324       3.554
# ...

# %%
import matplotlib.pyplot as plt
X.iloc[:,1:].corr()
#.corr() is used to evaluate correlation between the variables
# Out:
#                  TV     Radio  Newspaper
# TV         1.000000  0.054809   0.056648
# Radio      0.054809  1.000000   0.354104
# Newspaper  0.056648  0.354104   1.000000

# %%
df_salary = pd.read_csv('Salary_Data.csv')
df_salary.head()
# Out:
#    YearsExperience   Age  Salary
# 0              1.1  21.0   39343
# 1              1.3  21.5   46205
# 2              1.5  21.7   37731
# 3              2.0  22.0   43525
# 4              2.2  22.2   39891

# %%
X = df_salary[['YearsExperience', 'Age']]
y = df_salary['Salary']
# salary =  b0*1 + b1*YearsExperienece + b2*Age

# %%
X = sm.add_constant(X)
X
# Out:
#     const  YearsExperience   Age
# 0     1.0              1.1  21.0
# 1     1.0              1.3  21.5
# 2     1.0              1.5  21.7
# 3     1.0              2.0  22.0
# 4     1.0              2.2  22.2
# 5     1.0              2.9  23.0
# 6     1.0              3.0  23.0
# 7     1.0              3.2  23.3
# 8     1.0              3.2  23.3
# 9     1.0              3.7  23.6
# 10    1.0              3.9  23.9
# 11    1.0              4.0  24.0
# 12    1.0              4.0  24.0
# 13    1.0              4.1  24.0
# 14    1.0              4.5  25.0
# 15    1.0              4.9  25.0
# 16    1.0              5.1  26.0
# 17    1.0              5.3  27.0
# 18    1.0              5.9  28.0
# 19    1.0              6.0  29.0
# 20    1.0              6.8  30.0
# 21    1.0              7.1  30.0
# 22    1.0              7.9  31.0
# 23    1.0              8.2  32.0
# 24    1.0              8.7  33.0
# 25    1.0              9.0  34.0
# 26    1.0              9.5  35.0
# ...

# %%
model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.960
# Model:                            OLS   Adj. R-squared:                  0.957
# Method:                 Least Squares   F-statistic:                     323.9
# Date:                Wed, 16 Jun 2021   Prob (F-statistic):           1.35e-19
# Time:                        11:26:36   Log-Likelihood:                -300.35
# No. Observations:                  30   AIC:                             606.7
# Df Residuals:                      27   BIC:                             610.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
import matplotlib.pyplot as plt
X.iloc[:,1:].corr()
# Out:
#                  YearsExperience       Age
# YearsExperience         1.000000  0.987258
# Age                     0.987258  1.000000

# %% [markdown]
# Since both are highly correlated now we have to emit one which has higher p value. Here Age = 0.165 has high p-value so it will be omitted.

# %%
X = df_salary[['YearsExperience']]
X = sm.add_constant(X)
X
# Out:
#     const  YearsExperience
# 0     1.0              1.1
# 1     1.0              1.3
# 2     1.0              1.5
# 3     1.0              2.0
# 4     1.0              2.2
# 5     1.0              2.9
# 6     1.0              3.0
# 7     1.0              3.2
# 8     1.0              3.2
# 9     1.0              3.7
# 10    1.0              3.9
# 11    1.0              4.0
# 12    1.0              4.0
# 13    1.0              4.1
# 14    1.0              4.5
# 15    1.0              4.9
# 16    1.0              5.1
# 17    1.0              5.3
# 18    1.0              5.9
# 19    1.0              6.0
# 20    1.0              6.8
# 21    1.0              7.1
# 22    1.0              7.9
# 23    1.0              8.2
# 24    1.0              8.7
# 25    1.0              9.0
# 26    1.0              9.5
# 27    1.0              9.6
# 28    1.0             10.3
# 29    1.0             10.5

# %%
model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     622.5
# Date:                Wed, 16 Jun 2021   Prob (F-statistic):           1.14e-20
# Time:                        11:31:52   Log-Likelihood:                -301.44
# No. Observations:                  30   AIC:                             606.9
# Df Residuals:                      28   BIC:                             609.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...
